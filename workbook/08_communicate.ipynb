# %% [markdown]
# # 08 · Communication
#
# **Phase skill: writing findings for someone who will never run your code.**
#
# No new computation. Everything you need is already in notebooks 05–07 and in
# `reports/`. Your reader is **a GM who has never seen a regression** and doesn't want
# to — they want to know what to trust about monster levels and what to do about it.
#
# Write a **findings memo of 300–500 words** in the memo cell below.

# %% [markdown]
# ## Structure (use these four sections)
#
# 1. **What was measured** — two or three sentences. Name the data (243 Shadowdark
#    monsters, their statblocks, 2000 simulated fights per monster) and the question,
#    in table language, not model language.
# 2. **The three most defensible findings** — one short paragraph each. *Defensible*
#    means: survived notebook 07, and you can point at the number or chart it rests on.
#    Candidates you've earned: what a statblock does/doesn't determine about LV, which
#    stat matters most, what the band means say about tiers, which monsters are
#    mispriced, how well LV tracks simulated difficulty.
# 3. **One limitation** — the single caveat the reader most needs. (Leakage? Sample
#    size? The simulator's assumptions? Ordinal LV?) Pick one; a list of ten hedges
#    reads as zero.
# 4. **One recommendation** — something a GM can *do* at the table with your findings.
#
# Translation discipline: every statistical term must either be absent or explained in
# game terms (e.g., not "R² = 0.82" but "a monster's statblock pins down most of its
# level — but not all: about one level in five is design judgment").

# %% [markdown]
# ## Your memo
#
# ---
#
# *Replace this line with the memo.*

# %% [markdown]
# ## Self-score
#
# Run the cell after replacing every `None`. Be harsh — this is the one notebook where
# nobody can check you but you.

# %%
# Score yourself honestly: replace each None with True or False, then run the cell.
checklist = {
    "Word count is between 300 and 500": None,
    "A GM with no stats background could read every sentence aloud without stumbling": None,
    "Each finding cites its evidence (a number, a chart, or a table)": None,
    "No unexplained jargon -- R-squared, residual, correlation are explained or absent": None,
    "Exactly one limitation, stated plainly, not buried in hedges": None,
    "The recommendation tells a GM what to DO differently at the table": None,
    "Numbers are rounded to what the reader needs, not what the float gave you": None,
}

unanswered = [item for item, v in checklist.items() if v is None]
if unanswered:
    print(f"{len(unanswered)} item(s) not yet scored -- set each to True or False:")
    for item in unanswered:
        print(" -", item)
else:
    score = sum(checklist.values())
    print(f"Self-score: {score}/{len(checklist)}")
    if score < len(checklist):
        print("The False items are your edit list -- revise the memo, then re-score.")
    else:
        print("Ship it. Send the memo to an actual GM and see which sentence they question first.")

# %% [markdown]
# ## The lifecycle, one last time
#
# Your first course will ask you to describe the phases of a data-analytics lifecycle.
# You have now personally run all seven. Fill in the right column from memory — one
# concrete sentence about *this* project per phase, no notebook peeking until you're
# done:
#
# | # | Phase | Notebook(s) | What you actually did (fill in) |
# |---|-------|-------------|----------------------------------|
# | 1 | Problem framing / business understanding | 01 | *…* |
# | 2 | Data acquisition | 02 | *…* |
# | 3 | Storage & data management | 03 | *…* |
# | 4 | Cleaning & preparation | 04 | *…* |
# | 5 | Exploration & visualization | 05 | *…* |
# | 6 | Modeling & validation | 06, 07 | *…* |
# | 7 | Communication | 08 | *…* |
#
# Keep this table — it is a ready-made answer for your course's reflection task, in your
# own words, about work you actually did.
